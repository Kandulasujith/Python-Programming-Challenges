# %%
#1
print("Hello, World!")
# Out:
# Hello, World!

# %%
#2
n=int(input())
if n%2==1:
    print('Weird')
elif n%2==0:
    if n in range(2,5):
        print('Not Weird')
    elif n in range(6,20):
        print('Weird')
    elif n>20:
        print('Not Weird')
# Out:
#  15
# Weird

# %%
#3
a=int(input())
b=int(input())
print(a+b)
print(a-b)
print(a*b)
# Out:
#  3
#  5
# 8
# -2
# 15

# %%
#4
a=int(input())
b=int(input())
print(a//b)
print(a/b)
# Out:
#  3
#  5
# 0
# 0.6

# %%
#5
n=int(input())
for x in range(0,n):
    print(x**2)
# Out:
#  4
# 0
# 1
# 4
# 9

# %%
#6
def is_leap(year):
    leap=False
    if year % 400 == 0:
        leap=True
    elif year % 100 == 0:
        leap=False
    elif year % 4 == 0:
        leap=True
    else:
        leap=False
    return leap
year = int(input())
print(is_leap(year))
# Out:
#  2200
# False

# %%
#7
n=int(input())
for x in range(1,n+1):
    print(x,end='')
# Out:
#  5
# 12345
